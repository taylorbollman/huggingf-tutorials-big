# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo (to revision update/hf) to /tmp/pip-req-build-4nqmxnio
#   Running command git clone -q https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-4nqmxnio
#   Running command git checkout -b update/hf --track origin/update/hf
#   Switched to a new branch 'update/hf'
#   Branch 'update/hf' set up to track remote branch 'update/hf' from 'origin'.
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied (use --upgrade to upgrade): rl-zoo3==2.0.0a9 from git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf in /usr/local/lib/python3.8/dist-packages
# Requirement already satisfied: gym==0.26.2 in /usr/local/lib/python3.8/dist-packages (from rl-zoo3==2.0.0a9) (0.26.2)
# Requirement already satisfied: pytablewriter~=0.64 in /usr/local/lib/python3.8/dist-packages (from rl-zoo3==2.0.0a9) (0.64.2)
# Requirement already satisfied: huggingface-sb3>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from rl-zoo3==2.0.0a9) (3.0)
# Requirement already satisfied: sb3-contrib>=2.0.0a9 in /usr/local/lib/python3.8/dist-packages (from rl-zoo3==2.0.0a9) (2.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from rl-zoo3==2.0.0a9) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.8/dist-packages (from rl-zoo3==2.0.0a9) (13.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from rl-zoo3==2.0.0a9) (6.0.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.8/dist-packages (from rl-zoo3==2.0.0a9) (3.4.0)
# Requirement already satisfied: importlib-metadata>=4.8.0; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (6.8.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (1.24.4)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.8/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (3.0.0)
# Requirement already satisfied: DataProperty<2,>=0.55.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.0.1)
# Requirement already satisfied: tabledata<2,>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.3.3)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.1.3)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/lib/python3/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (45.2.0)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.8/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (0.1.4)
# Requirement already satisfied: typepy[datetime]<2,>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.3.2)
# Requirement already satisfied: pathvalidate<3,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2.5.2)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.8/dist-packages (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (0.17.3)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.8/dist-packages (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (0.10.1)
# Requirement already satisfied: stable-baselines3>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.1.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from rich->rl-zoo3==2.0.0a9) (4.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.8/dist-packages (from rich->rl-zoo3==2.0.0a9) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /root/.local/lib/python3.8/site-packages (from rich->rl-zoo3==2.0.0a9) (2.16.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from optuna->rl-zoo3==2.0.0a9) (23.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.8/dist-packages (from optuna->rl-zoo3==2.0.0a9) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from optuna->rl-zoo3==2.0.0a9) (2.0.22)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from optuna->rl-zoo3==2.0.0a9) (1.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.8.0; python_version < "3.10"->gym==0.26.2->rl-zoo3==2.0.0a9) (3.17.0)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.8/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (5.2.0)
# Requirement already satisfied: pytz>=2018.9; extra == "datetime" in /usr/local/lib/python3.8/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2023.3.post1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0; extra == "datetime" in /usr/local/lib/python3.8/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.31.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.29.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.7.3)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.1.0+cu118)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py>=2.2.0->rich->rl-zoo3==2.0.0a9) (0.1.2)
# Requirement already satisfied: greenlet!=0.4.17; platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32"))))) in /usr/local/lib/python3.8/dist-packages (from sqlalchemy>=1.3.0->optuna->rl-zoo3==2.0.0a9) (3.0.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (1.2.4)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (6.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil<3.0.0,>=2.8.0; extra == "datetime"->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (1.26.18)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.0.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (9.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.8/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.12)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.8/dist-packages (from pandas->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2023.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.8/dist-packages (from Mako->alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy->torch>=1.13->stable-baselines3>=2.1.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.3.0)
# Building wheels for collected packages: rl-zoo3
#   Building wheel for rl-zoo3 (PEP 517) ... done
#   Created wheel for rl-zoo3: filename=rl_zoo3-2.0.0a9-py3-none-any.whl size=76401 sha256=19a39871638956ee3a15f1fe20524babdbf8f82cb5dc05301436bbb6650b1e28
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kl__h9h8/wheels/12/04/74/8dab6db462767d6a4a8e034e42b52b441c12b34a178ac8344d
# Successfully built rl-zoo3

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.8/dist-packages (0.29.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[atari]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[atari]) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[atari]) (1.24.4)
# Requirement already satisfied: importlib-metadata>=4.8.0; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from gymnasium[atari]) (6.8.0)
# Requirement already satisfied: shimmy[atari]<1.0,>=0.1.0; extra == "atari" in /usr/local/lib/python3.8/dist-packages (from gymnasium[atari]) (0.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.8.0; python_version < "3.10"->gymnasium[atari]) (3.17.0)
# Requirement already satisfied: ale-py~=0.8.1; extra == "atari" in /usr/local/lib/python3.8/dist-packages (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]) (0.8.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from ale-py~=0.8.1; extra == "atari"->shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]) (6.1.0)
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.8/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[accept-rom-license]) (1.24.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[accept-rom-license]) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[accept-rom-license]) (3.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from gymnasium[accept-rom-license]) (6.8.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license" in /usr/local/lib/python3.8/dist-packages (from gymnasium[accept-rom-license]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.8.0; python_version < "3.10"->gymnasium[accept-rom-license]) (3.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2.31.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (8.1.7)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (6.1.0)
# Requirement already satisfied: AutoROM.accept-rom-license; extra == "accept-rom-license" in /usr/local/lib/python3.8/dist-packages (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (0.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (1.26.18)

# %%
# !apt-get update
# !apt-get install -y python-opengl ffmpeg xvfb
# !pip install pyvirtualdisplay
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:5 http://security.ubuntu.com/ubuntu focal-security InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-opengl is already the newest version (3.1.0+dfsg-2build1).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# xvfb is already the newest version (2:1.20.13-1ubuntu1~20.04.8).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.8/dist-packages (3.0)

# %%
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.17.3; python_version >= "3.8" in /usr/local/lib/python3.8/dist-packages (from opencv-python) (1.24.4)

# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# !/usr/bin/python3 -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 2431760800
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 10000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cpu device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 399      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 642      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 437      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 444      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 453      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 460      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3420     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 456      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 459      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 462      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 125      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 464      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 6013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 466      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 6932     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 469      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 7507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 471      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 8278     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 472      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 9207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 473      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 9690     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 473      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 10175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 474      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 10831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 475      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 11452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 476      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 12131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 476      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 12904    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 478      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 13787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 478      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 14600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 479      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 15213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 479      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 15664    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 479      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 16252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 479      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 16994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 480      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 17352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 480      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 17970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 480      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 18985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 480      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 19401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 480      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 19877    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 481      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 20501    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 481      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 21500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 481      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 21990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 481      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 22573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 481      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 23583    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 481      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 24245    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=189.00 +/- 121.47
# Episode length: 2221.00 +/- 662.14
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.22e+03 |
# |    mean_reward      | 189      |
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 432      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 25023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 433      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 25606    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 434      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 26118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 435      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 26880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 436      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 27423    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 437      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 27968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 437      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 28416    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 438      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 29073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 439      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 29752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 439      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 30184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 440      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 30609    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 440      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 31170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 442      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 32172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 442      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 32632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 444      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 33623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 444      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 34255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 445      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 34882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 446      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 35703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 447      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 36799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 447      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 37452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 448      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 38005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 448      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 38606    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 449      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 39464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 449      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 40104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 450      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 40933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 451      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 41609    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 451      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 42170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 451      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 42825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 452      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 44041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 452      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 44481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 452      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 45021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 452      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 45824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 453      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 46642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 453      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 47362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 453      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 47997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 453      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 48377    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 454      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 49016    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 454      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 49632    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=165.00 +/- 115.20
# Episode length: 2135.80 +/- 680.13
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.14e+03 |
# |    mean_reward      | 165      |
# | rollout/            |          |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 433      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 50510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 433      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 50961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 434      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 51794    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 434      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 52477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 435      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 53238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 435      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 53766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 436      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 54675    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 437      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 55382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 437      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 56223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 438      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 56761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 438      |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 57384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 438      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 57837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 439      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 59029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 440      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 59489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 440      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 59993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 440      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 60537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 441      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 61224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 441      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 61762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 441      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 62299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 442      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 63366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 442      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 64010    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 442      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 64633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 442      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 65331    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 443      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 65954    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 443      |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 66585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 443      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 67230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 443      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 67747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 444      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 68278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 444      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 69033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 444      |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 69455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 444      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 69903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 445      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 70494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 445      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 71128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 445      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 71734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 446      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 72620    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 446      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 72999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 446      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 73568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 446      |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 74235    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=159.00 +/- 111.69
# Episode length: 1905.00 +/- 356.30
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.90e+03 |
# |    mean_reward      | 159      |
# | rollout/            |          |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 433      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 75049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 433      |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 75673    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 434      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 76155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 434      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 76560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 434      |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 77628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 434      |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 78156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.922    |
# ...
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 436      |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 81163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 436      |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 81586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 436      |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 82586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 437      |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 83175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 437      |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 84030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 437      |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 84815    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 438      |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 85254    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 438      |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 86206    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 438      |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 86956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 438      |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 87519    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 439      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 88167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 439      |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 88905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 439      |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 89631    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 439      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 90378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 440      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 90924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 440      |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 91397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 440      |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 92030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 440      |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 92616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 440      |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 93471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 441      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 94261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 441      |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 94645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 441      |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 95623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 441      |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 96210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 442      |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 97179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 442      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 97889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 442      |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 98510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 443      |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 99710    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=89.00 +/- 58.94
# Episode length: 1515.80 +/- 248.49
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.52e+03 |
# |    mean_reward      | 89       |
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    total_timesteps  | 100000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 427      |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 100284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 405      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 101377   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 344      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 395      |
# |    time_elapsed     | 257      |
# |    total_timesteps  | 101920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000363 |
# |    n_updates        | 479      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 387      |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 102375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 593      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 378      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 102909   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 727      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 368      |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 103454   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 863      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 351      |
# |    time_elapsed     | 296      |
# |    total_timesteps  | 104434   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000152 |
# |    n_updates        | 1108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 340      |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 105251   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 1312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 331      |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 105842   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 1460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 325      |
# |    time_elapsed     | 327      |
# |    total_timesteps  | 106374   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000155 |
# |    n_updates        | 1593     |
# ----------------------------------
